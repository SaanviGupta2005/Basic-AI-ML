# %%
pip install mysql-connector-python
# Out:
# Collecting mysql-connector-python
#   Downloading mysql_connector_python-8.3.0-cp39-cp39-win_amd64.whl (15.4 MB)
#      ---------------------------------------- 15.4/15.4 MB 1.6 MB/s eta 0:00:00
# Installing collected packages: mysql-connector-python
# Successfully installed mysql-connector-python-8.3.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import mysql.connector as sql
import pandas as pd

db_connection = sql.connect(host='localhost', database='ai', user='root', password='Saanvigup0312#')
db_cursor = db_connection.cursor()
db_cursor.execute('Select * from salaries')

table_rows = db_cursor.fetchall()

df=pd.DataFrame(table_rows)
df
# Out:
#             0                  1   \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148040  148646   Carolyn A Wilson
# 148041  148648     Joann Anderson
# 148042  148649        Leon Walker
# 148043  148650      Roy I Tillery
# 148044  148654          Joe Lopez
#
#                                                     2          3          4   \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY  167411.18       0.00
# 1                      CAPTAIN III (POLICE DEPARTMENT)  155966.02  245131.88
# 2                      CAPTAIN III (POLICE DEPARTMENT)  212739.13  106088.18
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC   77916.00   56120.71
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)  134401.60    9737.00
# ...                                                ...        ...        ...
# 148040                       Human Services Technician       0.00       0.00
# 148041                     Communications Dispatcher 2       0.00       0.00
# 148042                                       Custodian       0.00       0.00
# 148043                                       Custodian       0.00       0.00
# 148044                      Counselor, Log Cabin Ranch       0.00       0.00
#
#                5     6          7          8     9  10             11  12
# 0       400184.25        567595.43  567595.43  2011     San Francisco
# 1       137811.38        538909.28  538909.28  2011     San Francisco
# 2        16452.60        335279.91  335279.91  2011     San Francisco
# 3       198306.90        332343.61  332343.61  2011     San Francisco
# 4       182234.59        326373.19  326373.19  2011     San Francisco
# ...           ...   ...        ...        ...   ... ..            ...  ..
# 148040       0.00  0.00       0.00       0.00  2014     San Francisco  PT
# 148041       0.00  0.00       0.00       0.00  2014     San Francisco  PT
# 148042       0.00  0.00       0.00       0.00  2014     San Francisco  PT
# 148043       0.00  0.00       0.00       0.00  2014     San Francisco  PT
# 148044    -618.13  0.00    -618.13    -618.13  2014     San Francisco  PT
#
# [148045 rows x 13 columns]
